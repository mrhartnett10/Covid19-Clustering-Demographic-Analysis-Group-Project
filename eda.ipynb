# %% [markdown]
# ### Import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', None)
plt.style.use('ggplot')

# %% [markdown]
# ### Load Data

# %%
dmf = pd.read_csv('data/yun_data/output/covid_socio_2020.csv')
unemp_covid_df = pd.read_csv('data/yun_data/output/unemployment_covid_2020.csv')
covid_df = pd.read_csv('data/yun_data/output/covid_monthly_2020.csv')
df3 = pd.read_csv('data/yun_data/output/unemp_rate_2020.csv')
df4 = pd.read_csv('data/yun_data/output/cov_unemp_summary.csv')

# %% [markdown]
# ### EDA

# %%
dmf.head()
# Out:
#          Name Postal Code  Area size  Population size  Population density  \
# 0     Alabama          AL     135767          4903185           36.114704
# 1      Alaska          AK    1723337           731545            0.424493
# 2     Arizona          AZ     295234          7278717           24.654061
# 3    Arkansas          AR     137732          3017804           21.910696
# 4  California          CA     423967         39512223           93.196459
#
#    Senior Population  Young Population  Male Population  White Population  \
# 0               17.4              18.3             48.3              69.5
# 1               12.4              21.0             52.0              71.4
# 2               18.0              18.7             49.7              81.7
# 3               17.4              19.2             48.9              79.3
# 4               14.8              18.7             49.7              63.6
#
#    Africa-American Population  Hispanic population  Internet access  \
# ...

# %%
unemp_covid_df.head()
# Out:
#   covid_state  cases1  cases2  cases3   cases4   cases5    cases6    cases7  \
# 0     Alabama     0.0     0.0  1063.0   6124.0  11013.0   20277.0   49789.0
# 1      Alaska     0.0     0.0   129.0    231.0    124.0     658.0    2574.0
# 2     Arizona     1.0     0.0  1288.0   6366.0  12281.0   59292.0   94782.0
# 3    Arkansas     0.0     0.0   523.0   2758.0   3972.0   13524.0   21734.0
# 4  California     3.0     9.0  8221.0  42479.0  62207.0  126805.0  267482.0
#
#      cases8    cases9   cases10   cases11    cases12  casestotal  death1  \
# 0   38234.0   28272.0   38841.0   55911.0   111702.0    361226.0     0.0
# 1    2457.0    2672.0    7510.0   16221.0    14410.0     46986.0     0.0
# 2   27825.0   16672.0   27439.0   80871.0   193390.0    520207.0     0.0
# 3   18713.0   22473.0   28493.0   45169.0    67779.0    225138.0     0.0
# 4  207366.0  107619.0  114064.0  308697.0  1080647.0   2325599.0     0.0
#
# ...

# %%
df4.head()
# Out:
#   month  unemp_rate   cases  death
# 0   Jan        3.65       8      0
# 1   Feb        3.62      17      1
# 2   Mar        4.15  191784   5320
# 3   Apr       14.18  887884  60708
# 4   May       12.28  717317  41684

# %%
plt.figure(figsize = (14,8))

ax1 = plt.subplot(3, 1, 1)
ax1.plot(df4['month'],df4['cases'], color = 'blue')
ax1.set_title('Covid-19 Cases USA in 2020')
ax1.set_ylabel('Cases')

ax2 = plt.subplot(3, 1, 2, sharex=ax1)
ax2.plot(df4['death'], color = 'red')
ax2.set_title("Covid-19 mortality USA in 2020")

ax3 = plt.subplot(3, 1, 3, sharex=ax2)
ax3.plot(df4['unemp_rate'], color = 'purple' )
ax3.set_title('Unemplyment Rate USA in 2020')
plt.tight_layout();

# %% [markdown]
# #### Covid Cases has increased from January to December....

# %%
plt.figure(figsize=(8, 8))
sns.heatmap(dmf[['deaths_per_population', 'Population size',
       'Population density', 'Senior Population', 'Young Population',
       'Male Population', 'White Population', 'Africa-American Population',
       'Hispanic population','High school degree',
       'Bachelor degrees']].corr()[['deaths_per_population']].sort_values('deaths_per_population'),
            annot=True,
            cmap='coolwarm',
            vmin=-1, 
            vmax=1)
plt.title('Covid-19 Mortality and Social Features Correlations');

# %%
plt.figure(figsize=(8, 8))
sns.heatmap(dmf[['confirmed_per_population', 'Population size',
       'Population density', 'Senior Population', 'Young Population',
       'Male Population', 'White Population', 'Africa-American Population',
       'Hispanic population','High school degree',
       'Bachelor degrees']].corr()[['confirmed_per_population']].sort_values('confirmed_per_population'),
            annot=True,
            cmap='coolwarm',
            vmin=-1, 
            vmax=1)
plt.title('Covid-19 Cases and Social Features Correlations');

# %%
plt.figure(figsize=(8, 8))
sns.heatmap(dmf[['deaths_per_population','Internet access', 'Median household income', 'Poverty rate',
       'Uninsured', 'Household size', 'House Owner','unemp_year_rate']].corr()[['deaths_per_population']].sort_values('deaths_per_population'),
            annot=True,
            cmap='coolwarm',
            vmin=-1, 
            vmax=1)
plt.title('Covid-19 Mortality and Economic Features Correlations');

# %%
plt.figure(figsize=(8, 8))
sns.heatmap(dmf[['confirmed_per_population','Internet access', 'Median household income', 'Poverty rate',
       'Uninsured', 'Household size', 'House Owner','unemp_year_rate']].corr()[['confirmed_per_population']].sort_values('confirmed_per_population'),
            annot=True,
            cmap='coolwarm',
            vmin=-1, 
            vmax=1)
plt.title('Covid-19 Cases and Economic Features Correlations');

# %%
plt.figure(figsize=(8, 8))
sns.heatmap(dmf[['deaths_per_population','hospital',
       'hospital bed', 'ICU bed', 'ventilator usage', 'Nurses',
       'Medical Doctors']].corr()[['deaths_per_population']].sort_values('deaths_per_population'),
            annot=True,
            cmap='coolwarm',
            vmin=-1, 
            vmax=1)

plt.title('Covid-19 Mortality and Medical Features Correlations');

# %%
plt.figure(figsize=(8, 8))
sns.heatmap(dmf[['confirmed_per_population','hospital',
       'hospital bed', 'ICU bed', 'ventilator usage', 'Nurses',
       'Medical Doctors']].corr()[['confirmed_per_population']].sort_values('confirmed_per_population'),
            annot=True,
            cmap='coolwarm',
            vmin=-1, 
            vmax=1)

plt.title('Covid-19 Cases and Medical Features Correlations');

# %%
plt.figure(figsize=(10,14)) 

clrs = ['grey' if (x < dmf.deaths_per_population.mean()) else 'red' for x in dmf['deaths_per_population'].sort_values()]
sns.barplot(x='deaths_per_population', y= 'Name', data=dmf.sort_values('deaths_per_population'),palette=clrs)         
plt.title('Covid-19 Mortality in 2020')
plt.ylabel('')
plt.xlabel('Mortality per population');

# %%
plt.figure(figsize=(16,10)) 

clrs = ['grey' if (x < dmf.deaths_per_population.mean()) else 'red' for x in dmf['deaths_per_population'].sort_values()]
sns.barplot(x='Name', y= 'deaths_per_population', data=dmf.sort_values('deaths_per_population'),palette=clrs)         
plt.title('Covid-19 Mortality in 2020')
plt.xlabel('')
plt.ylabel('Mortality per population')
plt.xticks(rotation = 60);

# %%
plt.figure(figsize=(10,14)) 

#plt.barh(df3.sort_values(by = 'year_rate', ascending= False)['state'], df3.sort_values(by = 'year_rate', ascending= False)['year_rate'])
clrs = ['grey' if (x < df3.unemp_year_rate.mean()) else 'black' for x in df3['unemp_year_rate'].sort_values()]
sns.barplot(x='unemp_year_rate', y= 'state', data=df3.sort_values('unemp_year_rate'),palette=clrs)         
plt.xlabel('Unemployment Rate')
plt.ylabel('')
plt.title('Unemployment Rate in the US in 2020');

# %%
plt.figure(figsize=(16,10))

clrs = ['grey' if (x < df3.unemp_year_rate.mean()) else 'black' for x in df3['unemp_year_rate'].sort_values()]
sns.barplot(x= 'state', y='unemp_year_rate', data=df3.sort_values('unemp_year_rate'),palette=clrs)         
plt.xlabel('Unemployment Rate')
plt.ylabel('')
plt.title('Unemployment Rate in the US in 2020')
plt.xticks(rotation = 60);
